# %% [markdown]
# # 멀티모달 모델(이미지 인식) 샘플
#
# 이 노트북은 LangChain과 OpenAI의 GPT-4o를 사용하여 이미지를 인식하고 설명하는 예제입니다.

# %%
# 필요한 라이브러리 임포트 및 환경변수 로드
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
import base64
from IPython.display import Image, display

load_dotenv()
# Out:
# True

# %%
# 이미지 URL 설정
image_url = "https://t3.ftcdn.net/jpg/03/77/33/96/360_F_377339633_Rtv9I77sSmSNcev8bEcnVxTHrXB4nRJ5.jpg"

# 이미지 확인
display(Image(url=image_url, width=300))
# Out:
# <img src="https://t3.ftcdn.net/jpg/03/77/33/96/360_F_377339633_Rtv9I77sSmSNcev8bEcnVxTHrXB4nRJ5.jpg" width="300"/>

# %%
# 모델 초기화
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# 메시지 생성
message = HumanMessage(
    content=[
        {"type": "text", "text": "이 이미지를 한국어로 자세히 설명해줘."},
        {"type": "image_url", "image_url": {"url": image_url}},
    ]
)

# 실행
response = llm.invoke([message])

# %%
response
# Out:
# AIMessage(content='이 이미지는 표 형식의 데이터 테이블을 보여줍니다. 표의 제목은 "TABLE 001: LOREM IPSUM DOLOR AMIS ENIMA ACCUMER TUNA"입니다. \n\n표는 다섯 개의 열로 구성되어 있으며, 각 열의 제목은 다음과 같습니다:\n1. Loremis\n2. Amis terim\n3. Gáto lepis\n4. Tortores\n\n각 행은 다양한 데이터 항목을 포함하고 있습니다. 예를 들어, 첫 번째 행은 "Lorem dolor siamet"라는 항목으로 시작하며, 그에 대한 데이터는 8,288, 123%, YES, $89입니다. \n\n다른 행들도 유사한 형식으로 구성되어 있으며, 각 항목에 대한 수치, 백분율, YES/NO 여부, 금액 등이 포함되어 있습니다. \n\n표 아래에는 작은 글씨로 "Lorem ipsum"으로 시작하는 설명 텍스트가 있습니다. 이 텍스트는 일반적으로 자리 표시자 텍스트로 사용됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 222, 'prompt_tokens': 444, 'total_tokens': 666, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_fa7f5b168b', 'id': 'chatcmpl-D3tUQCXhYOiUxOcS3AXfWeA4IatTq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1188-1667-7d23-b17a-9683e5449fd4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 444, 'output_tokens': 222, 'total_tokens': 666, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
